# %%
import matplotlib.pyplot as plt
data=[10,20,20,30,30,40,40]

# %%
plt.hist(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
df=pd .read_csv(r"C:\Users\SCA_11\Desktop\harish\Churn_Modelling (4).csv")

# %%
print(df)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.isnull()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False    False        False      False   False  False
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False      False   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
# ...

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
plt.figure(figsize=(8,6))
plt.hist(df['Age'],bins=10,edgecolor='black')
plt.title('distribution of age')
plt.xlabel('age')
plt.ylabel('frequency')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(df['Age'],bins=10,edgecolor='black')
plt.title('distribution of age')
plt.xlabel('age')
plt.ylabel('frequency')
plt.grid(axis='y',alpha=0.75)
plt.show()

# %%
cont_col=['Age','CreditScore','Balance','EstimatedSalary'] 
for col in cont_col: 
    print(f"\n{col}Exploration") 
    print(df[col].describe()) 
    print('_' * 60) 
    plt.hist(df[col],bins=10,edgecolor='black') 
    plt.title(f"\n distribution of {col}")
    plt.grid(axis='y',alpha=0.75)
    plt.show()
# Out:
# AgeExploration
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: Age, dtype: float64
# ____________________________________________________________
# CreditScoreExploration
# count    10000.000000
# mean       650.528800
# std         96.653299
# min        350.000000
# 25%        584.000000
# 50%        652.000000
# 75%        718.000000
# max        850.000000
# Name: CreditScore, dtype: float64
# ____________________________________________________________
# BalanceExploration
# count     10000.000000
# mean      76485.889288
# std       62397.405202
# min           0.000000
# 25%           0.000000
# 50%       97198.540000
# 75%      127644.240000
# max      250898.090000
# Name: Balance, dtype: float64
# ____________________________________________________________
# EstimatedSalaryExploration
# count     10000.000000
# ...

# %%
for col in cont_col:
    fig, axes=plt.subplots(1,2,figsize=(14,6))
    
    axes[0].hist(df[col],bins=10,edgecolor='black') 
    axes[0].set_title(f'Distribution of {col}')
    axes[0].set_xlabel(col)
    axes[0].set_ylabel('Frequency')
    axes[0].grid(axis='y',alpha=0.75)
    
    
    axes[1].boxplot(df[col])
    axes[1].set_title(f'boxplot of {col}')
    axes[1].set_ylabel(col)
    axes[1].grid(axis='y',alpha=0.75)

# %%
Numerical_columns = df.select_dtypes(include=['int64','float64']).columns
Numerical_columns
# Out:
# Index(['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
numerical_df = df[Numerical_columns]
correlation_matrix=numerical_df.corr()

plt.figure(figsize=(12,10))
sns.heatmap(correlation_matrix,annot = True,cmap = 'coolwarm',fmt='.2f')
plt. title('correlation matrix of numerical features')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['Age'],y=df['CreditScore'])
plt.show()

# %%
plt.figure(figsize=(5,5))
custom_colors=['red','yellow','red']
sns.barplot(x=df['Geography'],y=df['Age'],palette=custom_colors)
plt.show()
# Out:
# C:\Users\SCA_11\AppData\Local\Temp\ipykernel_3504\2221089589.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Geography'],y=df['Age'],palette=custom_colors)

# %%
plt.figure(figsize=(5,5))
sns.lineplot(x=df['Age'],y=df['CreditScore'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['Age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
custom_colors=['red','yellow','red']
sns.boxplot(x=df['Gender'],y=df['CreditScore'],palette=custom_colors)
plt.show()
# Out:
# C:\Users\SCA_11\AppData\Local\Temp\ipykernel_3504\905556695.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Gender'],y=df['CreditScore'],palette=custom_colors)
# C:\Users\SCA_11\AppData\Local\Temp\ipykernel_3504\905556695.py:3: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.boxplot(x=df['Gender'],y=df['CreditScore'],palette=custom_colors)

# %% [raw]
# plt.figure(figsize=(5,5))
# custom_colors=['red','yellow','red']
# sns.violinplot(x=df['Gender'],y=df['CreditScore'],palette=custom_colors)
# plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.kdeplot(data=df,x="Age",fill=True)
plt.show()

# %%
import plotly.express as px 
fig = px.box(df,x='Geography',y='EstimatedSalary',color='Geography',title='interactive')
fig.show()

# %%
fig = px.histogram(df,x='Geography',y='EstimatedSalary',color='Geography',title='interactive')
fig.show()

# %%
fig = px.bar(df,x='Geography',y='EstimatedSalary',color='Geography',title='interactive')
fig.show()

# %%
fig = px.scatter(df,x='Geography',y='EstimatedSalary',color='Geography',title='interactive')
fig.show()

# %%
fig = px.line(df,x='Geography',y='EstimatedSalary',color='Geography',title='interactive')
fig.show()

# %%
fig = px.violin(df,x='Geography',y='EstimatedSalary',color='Geography',title='interactive')
fig.show()
